# %% [markdown]
# # <center> INX FUTURE INC EMPLOYEE PERFORMANCE ANALYSIS

# %% [markdown]
# ## <center> BUISNESS CASE:BASED ON GIVEN FEATURE OF DATASET WE NEED TO PREDICT THE PERFOMANCE RATING OF EMPLOYEE

# %% [markdown]
# # Summary Report
# - The employee performance dataset contains various features related to employees and their performance ratings. The goal of this analysis is to uncover patterns and insights into the factors that influence employee performance and identify areas for improvement.
#
# ## Dataset Overview
#
# - The dataset contains **1200** rows and **28** columns.
# - No null values are present in the dataset.
# - No columns in the dataset have constant values.
# - No duplicated rows are present in the dataset.
#
# ## Columns Information
#
# - There are a total of **28** columns in the dataset.
# - Column names: `EmpNumber`, `Age`, `Gender`, `EducationBackground`, `MaritalStatus`, `EmpDepartment`, `EmpJobRole`, `BusinessTravelFrequency`, `DistanceFromHome`, `EmpEducationLevel`, `EmpEnvironmentSatisfaction`, `EmpHourlyRate`, `EmpJobInvolvement`, `EmpJobLevel`, `EmpJobSatisfaction`, `NumCompaniesWorked`, `OverTime`, `EmpLastSalaryHikePercent`, `EmpRelationshipSatisfaction`, `TotalWorkExperienceInYears`, `TrainingTimesLastYear`, `EmpWorkLifeBalance`, `ExperienceYearsAtThisCompany`, `ExperienceYearsInCurrentRole`, `YearsSinceLastPromotion`, `YearsWithCurrManager`, `Attrition`, `PerformanceRating`.
# - **9** columns are categorical, and the remaining columns are numerical.
#
# ## Categorical Columns
#
# - Categorical columns: `EmpNumber`, `Gender`, `EducationBackground`, `MaritalStatus`, `EmpDepartment`, `EmpJobRole`, `BusinessTravelFrequency`, `OverTime`, `Attrition`.
# - No missing values or duplicated rows are present in these columns.
#
# ## Numerical Columns
#
# - Numerical columns: `Age`, `DistanceFromHome`, `EmpEducationLevel`, `EmpEnvironmentSatisfaction`, `EmpHourlyRate`, `EmpJobInvolvement`, `EmpJobLevel`, `EmpJobSatisfaction`, `NumCompaniesWorked`, `EmpLastSalaryHikePercent`, `EmpRelationshipSatisfaction`, `TotalWorkExperienceInYears`, `TrainingTimesLastYear`, `EmpWorkLifeBalance`, `ExperienceYearsAtThisCompany`, `ExperienceYearsInCurrentRole`, `YearsSinceLastPromotion`, `YearsWithCurrManager`, `PerformanceRating`.
#
# ## String Values in Categorical Columns
#
# - Categorical columns with string values: `EmpNumber`, `Gender`, `EducationBackground`, `MaritalStatus`, `EmpDepartment`, `EmpJobRole`, `BusinessTravelFrequency`, `OverTime`, `Attrition`.
#
# ## Target Variable (PerformanceRating)
#
# - PerformanceRating has three unique values: **2**, **3**, and **4**.
# - The dataset is unbalanced, with the majority of entries having a PerformanceRating of **3** (**874** entries), followed by **2** (**194** entries) and **4** (**132** entries).

# %% [markdown]
# The dataset contains employee-related features that can help analyze performance. Each column has a different meaning and impact on performance, such as:
#
# - **EmpNumber**: A unique identifier for each employee.
#
# - **Age**: The age of employees, which may affect experience and performance characteristics.
# - **Gender**: The gender of employees, which can reveal patterns and diversity.
# - **EducationBackground**: The educational backgrounds of employees, which may correlate with skill sets and performance.
# - **MaritalStatus**: The marital status of employees, which can influence job satisfaction and work-life balance.
# - **EmpDepartment**: The department where employees work, which can reveal insights for improvement and strategy.
# - **EmpJobRole**: The specific job role or position of employees, which comes with distinct responsibilities and performance expectations.
# - **BusinessTravelFrequency**: How frequently employees travel for business, which can affect adaptability and performance variations.
# - **DistanceFromHome**: The distance between employees' home and workplace, which may influence job satisfaction and punctuality.
# - **EmpEducationLevel**: The highest education level attained by employees, which may correlate with advanced skills and qualifications.
# - **EmpEnvironmentSatisfaction**: Employees' satisfaction with the work environment, which is linked to better performance.
# - **EmpJobInvolvement**: The level of job involvement or engagement, which may indicate commitment and performance improvement.
# - **EmpJobSatisfaction**: Employees' job satisfaction, which influences motivation and performance outcomes.
# - **NumCompaniesWorked**: The number of companies employees worked for before the current one, which may bring diverse perspectives but also impact adaptability.
# - **OverTime**: Whether employees work overtime, which may lead to burnout or dedication, influencing performance.
# - **EmpLastSalaryHikePercent**: The percentage increase in the employee's last salary hike, which is tied to salary satisfaction, motivation and performance.
# - **EmpRelationshipSatisfaction**: Employees' satisfaction with work relationships, which can contribute to well-being and performance enhancement.
# - **EmpWorkLifeBalance**: Employees' satisfaction with their work-life balance, which can affect their well-being, productivity, and performance.
# - **TrainingTimesLastYear**: The number of training sessions employees attended in the last year, which can help them develop new skills, improve existing ones, and enhance their performance.
# - **TotalWorkExperienceInYears**: The total years of work experience employees have, which can bring valuable knowledge, expertise, and confidence, potentially influencing performance.
# - **ExperienceYearsAtThisCompany**: The number of years employees have worked at the current company, which can indicate loyalty, commitment, and familiarity, which may impact performance.
# - **ExperienceYearsInCurrentRole**: The number of years employees have spent in their current job role, which can indicate mastery, stability, and satisfaction, which may affect performance.
# - **YearsSinceLastPromotion**: The time since the last promotion employees received, which is often a reward for good performance, and can also motivate them to perform better in the future.
# - **YearsWithCurrManager**: The number of years employees have worked with their current manager, which can indicate trust, rapport, and feedback, which may influence performance.
# - **Attrition**: Whether employees have left the company or not, which is often a result of poor performance, dissatisfaction, or other factors, and can also affect the performance of the remaining employees.
#
# ## Target Variable
#
# - **PerformanceRating**: The employee performance rating, which is the main variable of interest. Performance rating is a measure of how well employees perform their tasks and achieve their goals. Analyzing the performance rating can help identify the factors that influence it and the areas for improvement.
#
# ## Analysis Goals
#
# - Uncover patterns and insights into factors influencing performance
# - Analyze the distribution of performance ratings
# - Identify relationships between performance ratings and other variables

# %% [markdown]
# ## Data Analysis
#
# The project explores the data set using descriptive statistics and visualizations. The project also identifies potential areas of improvement and recommendations for the organization based on the findings. Some of the key insights from the project are:
#
# - The organization exhibits a **gender imbalance**, with a significantly higher number of male employees compared to female employees. This gender distribution may impact workplace dynamics and diversity initiatives.
#
# - The most common education background is in Life Sciences, followed by Medical, Marketing, Technical Degree, Other, and Human Resources. This diversity in educational backgrounds contributes to a varied skill set within the workforce.
#
# - The majority of employees are married, followed by single and divorced individuals. Understanding marital status demographics can provide insights into potential factors affecting employee motivation and work-life balance.
#
# - The majority of employees report high levels of satisfaction with their work environment, job involvement, and job satisfaction. A positive work culture is reflected in the distribution of satisfaction levels.
#
# - Sales executives and developers are the most numerous job roles, indicating potential areas of strength within the organization. However, the scarcity of technical architects suggests a gap that may need attention.
#
# - Most employees travel rarely, with only a small percentage traveling frequently. This information can be valuable for understanding the organization's mobility expectations and potential impacts on employee performance.
#
# - The majority of employees live within 5 miles of the workplace, suggesting proximity as a factor in residence choices. Outliers, such as those living more than 25 miles away, may indicate unique preferences or circumstances.
#
# - A significant number of employees hold a bachelor's degree, followed by those with a master's degree. This distribution provides insights into the educational qualifications of the workforce.
#
# - The distribution of hourly rates is diverse, indicating varied compensation structures within the organization. Further analysis can explore the relationship between hourly rates and other employee factors.
#
# - The majority of employees are in lower job levels, with the count decreasing as job levels increase. This suggests a hierarchical structure with opportunities for career progression.
#
# - Salary hike percentages are diverse, with the majority receiving hikes of 14% or less. Understanding the distribution can inform discussions about compensation fairness and structures.
#
# - Most employees report high levels of relationship satisfaction at work, contributing to a positive workplace environment.
#
# - Work experience is diverse, with a significant portion of employees having 10 years or less. This indicates a mix of experienced and relatively newer employees.
#
# - The majority of employees prefer shorter training sessions, with 2 and 3 hours being the most common. This insight can guide the design and delivery of training programs.
#
# - Employees generally report high levels of satisfaction with their work-life balance, reflecting a positive aspect of the organizational culture.
#
# - The distribution of experience years at the current company is right-skewed, indicating some employees with relatively higher tenure. This could influence organizational stability.
#
# - The distribution of experience years in the current role is right-skewed, suggesting diversity in the duration of roles. Understanding this can aid in optimizing role transitions and employee development.
#
# - Most employees experienced a promotion within the last year or less. This may indicate a focus on career progression and opportunities for growth within the organization.
#
# - The distribution of years with the current manager is right-skewed, suggesting some employees have longer working relationships with their managers. Strong relationships may positively impact performance.
#
# - The organization demonstrates a low attrition rate, with the majority of employees choosing to stay. This indicates employee satisfaction and loyalty.
#
# - The most common performance rating is 3 (Excellent), followed by 2 (Good). The distribution provides insights into the overall performance of the workforce.

# %% [markdown]
# - **Age Distribution**: The data shows a wide range of ages across different departments, reflecting a diverse mix of experience levels. The youngest employee is 18 years old and works in the Research & Development department, while the oldest employee is 60 years old and works in the Sales department. The mean age of the employees is 36.92 years, with a standard deviation of 9.13 years.
#
# - **Job Satisfaction by Gender**: The data reveals a slight difference in job satisfaction levels between male and female employees. Male employees have the highest mean job satisfaction of 2.75, while female employees have a mean job satisfaction of 2.68. The job satisfaction ratings range from 1 (Low) to 4 (Very High).
#
# - **Attrition Analysis**: The data indicates a significant impact of marital status on attrition rates. Single employees have the highest total attrition count, with 94 individuals leaving the company. Single employees also have the highest mean attrition rate of 24.48%, indicating a higher proportion of attrition within this marital status category. Divorced employees show the minimum attrition rate of 10.09%, suggesting higher retention within this group. Married employees have a mean attrition rate of 12.43%.
#
# - **Overtime Work by Gender and Marital Status**: The data demonstrates a notable variation in overtime work patterns based on gender and marital status. The combination of males who are married and work overtime has the highest count (96 individuals). This insight can guide workforce management and scheduling strategies. The combination of females who are single and work overtime has the lowest count (12 individuals).
#
# - **Performance Ratings by Gender**: The data illustrates a similar distribution of performance ratings between male and female employees. Performance ratings range from 1 (Low) to 4 (Outstanding). Both genders predominantly receive ratings of 3 (Excellent), with males having a slightly higher count in this category (473 males vs. 452 females). Females have a slightly higher count in the ratings of 2 (Good) and 4 (Outstanding), while males have a slightly higher count in the rating of 1 (Low).
#
# - **Performance Rating by Number of Companies Worked**: The data suggests a potential positive correlation between performance ratings and the number of companies worked for. The average performance rating generally increases as the number of companies worked for increases, implying that employees with diverse work experiences tend to perform well. The highest average performance rating of 3.29 is observed for employees who have worked for six companies, while the lowest average performance rating of 2.90 is observed for employees who have worked for one company.
#
# - **Performance Rating by Distance from Home**: The data indicates slight variations in performance ratings based on the distance from home. Employees living within 15 miles generally have higher ratings than those living farther away. The highest average performance rating of 3.13 is observed for employees living within 5 miles, while the lowest average performance rating of 2.86 is observed for employees living between 26 and 30 miles.
#
# - **Job Satisfaction and Attrition**: The data reveals a potential connection between job satisfaction levels and retention. Employees who left the company (attrition: Yes) have a lower average job satisfaction of 2.52 compared to those who stayed (attrition: No) with an average satisfaction of 2.77. This finding suggests that improving job satisfaction could contribute to higher employee retention rates.
# - **Promotion Rates by Education Level**: The data shows relatively consistent promotion rates across different education levels, ranging from approximately 59% to 64%. The education levels range from 1 (Below College) to 5 (Doctorate). The highest promotion rate of 63.93% is observed for employees with education level 4 (Master's Degree), while the lowest promotion rate of 58.82% is observed for employees with education level 1 (Below College).
#
# - **Job Satisfaction by Hourly Rate**: The data indicates a relationship between hourly rates and job satisfaction levels. Job satisfaction varies across different hourly rates, with the mean satisfaction ranging from 2.58 to 3.16. Higher hourly rates tend to correspond with higher satisfaction levels. The highest average job satisfaction of 3.16 is observed for employees with an hourly rate of 100, while the lowest average job satisfaction of 2.58 is observed for employees with an hourly rate of 42.
#
# ## Implications and Recommendations
#
# Based on the key findings, the following implications and recommendations can be derived for human resource management and organizational development:
#
# - **Marital Status Impact**: The data suggests that marital status has a significant impact on attrition rates, especially for single employees. This implies that single employees may face more challenges or dissatisfaction in their work environment, leading to higher turnover. Therefore, it is recommended to implement targeted retention strategies for single employees, such as providing more social support, flexible work arrangements, or career development opportunities.
# - **Overtime Management**: The data reveals that the combination of males who are married and work overtime has the highest count, indicating a possible imbalance in workload distribution or work-life balance. This may result in lower job satisfaction, higher stress, or lower performance for this group of employees. Therefore, it is recommended to review the overtime work patterns and ensure a fair and efficient allocation of tasks and resources. Moreover, it is recommended to promote a healthy work-life balance for all employees, especially those who work overtime, by providing wellness programs, counseling services, or recognition and rewards.
# - **Performance and Experience**: The data indicates a positive correlation between performance ratings and the number of companies worked for, suggesting that employees with diverse work experiences tend to perform well. This implies that the company can benefit from encouraging diverse career paths for its employees, as well as attracting and retaining talent with varied backgrounds and skills. Therefore, it is recommended to foster a culture of learning and innovation, where employees are motivated to explore new opportunities, acquire new knowledge, and apply their skills in different contexts. Additionally, it is recommended to leverage the expertise and experience of high-performing employees, by providing mentoring, coaching, or knowledge sharing platforms.
# - **Proximity Influence**: The data shows slight variations in performance ratings based on the distance from home, implying that proximity to the workplace may influence employee performance. This may be due to factors such as commuting time, transportation costs, or environmental conditions. Therefore, it is recommended to consider the location and accessibility of the workplace, as well as the preferences and needs of the employees, when making decisions about workforce planning and development. Furthermore, it is recommended to provide alternative or flexible work options, such as telecommuting, remote work, or co-working spaces, for employees who live farther away or face commuting challenges.
# - **Attrition and Job Satisfaction Link**: The data reveals a potential connection between job satisfaction levels and retention, indicating that employees who left the company had lower job satisfaction than those who stayed. This suggests that improving job satisfaction could contribute to higher employee retention rates, as well as higher performance and productivity. Therefore, it is recommended to conduct regular surveys or feedback sessions to measure and monitor employee satisfaction, as well as to identify and address the factors that affect employee satisfaction, such as compensation, benefits, work environment, leadership, communication, or recognition.
# - **Education Level and Promotions**: The data shows relatively consistent promotion rates across education levels, suggesting a fair promotion system that does not discriminate based on educational qualifications. This implies that the company values the performance and potential of its employees, rather than their formal credentials. Therefore, it is recommended to continue to uphold the merit-based promotion system, as well as to ensure equal opportunities for career growth for all employees, regardless of their education level. Moreover, it is recommended to provide continuous learning and development opportunities for employees, such as training, education assistance, or certification programs, to enhance their skills and competencies.
#
# - **Hourly Rate and Job Satisfaction**: The data indicates a relationship between hourly rates and job satisfaction levels, suggesting that higher hourly rates tend to correspond with higher satisfaction levels. This implies that compensation is an important factor that influences employee satisfaction, as well as motivation and retention. Therefore, it is recommended to review and adjust the hourly rates periodically, based on market trends, industry standards, and employee performance. Additionally, it is recommended to implement a comprehensive and transparent reward system, that recognizes and rewards employees for their contributions, achievements, and behaviors, using both monetary and non-monetary incentives.

# %% [markdown]
# - The organization should implement **diversity and inclusion initiatives** to address the gender imbalance and create a more diverse workforce. This can improve organizational performance, innovation, and employee satisfaction.
#
# - The organization should conduct a **job role analysis** to identify the specific skills and competencies required for each role. This can help in refining recruitment strategies, providing targeted training, and ensuring that the workforce aligns with organizational goals.
#
# - The organization should explore the possibility of implementing **employee mobility programs** such as flexible work arrangements, remote work options, or job rotations. This can enhance employee satisfaction, work-life balance, and productivity.
#
# - The organization should analyze the relationship between **hourly rates** and other employee factors, such as performance ratings, job satisfaction, and years of experience. This can guide a comprehensive review of the compensation structure to ensure fairness and alignment with employee contributions.
#
# - The organization should promote and communicate **career development opportunities** within the organization. This can encourage employees to pursue additional training, certifications, and skills development to enhance their career growth.
#
# - The organization should consider the **proximity** of employees to the workplace and the potential challenges related to commuting. This can affect employee satisfaction, retention, and performance. The organization may offer flexible work arrangements, remote work options, or transportation benefits to address these challenges.
#
# - The organization should conduct regular **employee satisfaction surveys** to gather feedback on various aspects of the workplace, such as leadership, communication, and work environment. This can help in addressing specific concerns and continuously improving the employee experience.
#
# - The organization should implement and enhance **performance recognition programs** to acknowledge and reward employees for their outstanding contributions. This can positively impact job satisfaction, motivation, and overall performance.
#
# - The organization should establish **mentorship and coaching programs** to foster professional development and build strong relationships between employees and their managers. This can contribute to higher levels of job satisfaction and employee retention.
#
# - The organization should foster a **continuous learning culture** by providing ongoing training opportunities, workshops, and access to learning resources. This can contribute to skill development, employee engagement, and overall performance improvement.
#
# - The organization should develop a robust **succession planning strategy** to identify and prepare high-potential employees for key roles within the organization. This ensures a smooth transition and maintains organizational stability.
#
# - The organization should conduct thorough **exit interviews** with employees who choose to leave the organization to understand the reasons behind attrition. This can help in addressing any systemic issues and improving retention strategies.
#
# - The organization should implement a transparent and regular **performance feedback mechanism** that encourages open communication between employees and managers. This can lead to continuous improvement, skill development, and increased job satisfaction.
#
# - The organization should prioritize **employee well-being** by offering wellness programs, stress management initiatives, and mental health support. A healthy work-life balance contributes to higher job satisfaction and overall performance.
